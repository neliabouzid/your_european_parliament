# %% [markdown]
# # Manipulating data for import on PostgreSQL

# %% [markdown]
# ## 1. Library and data import

# %%
import pandas as pd
import json
from ast import literal_eval
from sqlalchemy import create_engine
import os

# %%
df_final_act = pd.read_csv('cod_final_act_general_summary.csv')
df_final_act_proposal_summary_1 = pd.read_csv('cod_completed_proposal_general_summary_0_5.csv')
df_final_act_proposal_summary_2 = pd.read_csv('cod_completed_proposal_general_summary_5_10.csv')
df_final_act_proposal_summary_3 = pd.read_csv('cod_completed_proposal_general_summary_10_15.csv')
df_final_act_proposal_summary_4 = pd.read_csv('cod_completed_proposal_general_summary_15_17.csv')

# %%
df_proposal_1 = pd.read_csv('cod_proposal_general_summary_0_5.csv')
df_proposal_2 = pd.read_csv('cod_proposal_general_summary_5_10.csv')
df_proposal_3 = pd.read_csv('cod_proposal_general_summary_10_20.csv')
df_proposal_4 = pd.read_csv('cod_proposal_general_summary_20_25.csv')

# %% [markdown]
# ## 2. Data manipulation

# %% [markdown]
# ### 2.1 Handle ongoing procedures

# %%
df_proposal = pd.concat([df_proposal_1, df_proposal_2, df_proposal_3, df_proposal_4])

# %%
df_proposal = df_proposal.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'Unnamed: 0.2'])

# %%
# Adding missing columns that are present in the PostgreSQL database to avoid unmatching columns
df_proposal['resolution_text_2'] = None
df_proposal['proposition_text_2'] = None
df_proposal['text_adopted_others_2'] = None
df_proposal['resolution_text_3'] = None
df_proposal['proposition_text_3'] = None
df_proposal['text_adopted_others_3'] = None
df_proposal['final_act_summary'] = None

# %%
df_proposal
# Out:
#                                                  url       reference  \
# 0  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0255(COD)
# 1  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0405(COD)
# 2  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0540(COD)
# 3  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0550(COD)
# 4  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0227(COD)
# 0  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0423(COD)
# 1  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0422(COD)
# 2  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0385(COD)
# 3  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0103(COD)
# 4  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0258(COD)
# 0  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0590(COD)
# 1  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0237(COD)
# 2  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0312(COD)
# 3  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0241(COD)
# 4  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0424(COD)
# 5  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0071(COD)
# 6  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0381(COD)
# 7  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0383(COD)
# 8  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0396(COD)
# 9  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0073(COD)
# 0  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0384(COD)
# 1  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0240(COD)
# 2  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0361(COD)
# 3  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0395(COD)
# 4  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0399(COD)
#
#                                                title  \
# 0                        Justice programme 2028-2034
# 1  Placing on the market of genetically modified ...
# 2  Union support for asylum, migration and integr...
# 3                      'AgoraEU' programme 2028–2034
# 4                                      Global Europe
# 0  Calculation of emission credits for heavy-duty...
# 1                                                NaN
# 2       Amendments to the Critical Raw Materials Act
# 3  Incentivising defence-related investments in t...
# 4  Pericles V exchange, assistance and training p...
# 0  Establishing the Single Market and Customs Pro...
# 1  Amendments to the Common Market Organisation (...
# 2  Economic and budgetary surveillance of Member ...
# 3               Common Agricultural Policy 2028–2034
# 4  Exemption of certain N2 electric vehicles from...
# 5  Amending certain agricultural products Regulat...
# 6  Banks and financial markets: settlement finali...
# 7  Further development of capital market integrat...
# 8  Suspending the application of the rules on the...
# 9  European Globalisation Adjustment Fund for Dis...
# 0         Monitoring and controlling drug precursors
# 1  European Fund for economic, social and territo...
# 2  Sustainability-related disclosures in the fina...
# 3  Suspending the application of the rules on the...
# 4   Trans-European energy infrastructure: guidelines
#
#                                             subjects  \
# 0  7.40.02 Judicial cooperation in civil and comm...
# 1  3.10.09.06 Agro-genetics, GMOs, 4.60.02 Consum...
# 2  7.10 Free movement and integration of third-co...
# 3  1.20 Citizen's rights, 4.10.03 Child protectio...
# 4  6.20 Common commercial policy in general, 8.70...
# 0  3.20.05 Road transport: passengers and freight...
# 1                                                NaN
# 2  3.40 Industrial policy, 3.40.14 Industrial com...
# 3  3.40.09 Defence and arms industry, 4.70.01 Str...
# 4  5.20.02 Single currency, euro, euro area, 7.30...
# 0  2.10.01 Customs union, tax and duty-free, Comm...
# 1  3.10 Agricultural policy and economies, 3.10.0...
# 2  4.70.01 Structural funds, investment funds in ...
# 3  3.10 Agricultural policy and economies, 3.10.0...
# 4  3.20.06 Transport regulations, road safety, ro...
# 5  3.10 Agricultural policy and economies, 3.10.0...
# 6  2.50.03 Securities and financial markets, stoc...
# 7  2.50.03 Securities and financial markets, stoc...
# 8  3.70.12 Waste management, domestic waste, pack...
# 9  4.15.05 Industrial restructuring, job losses, ...
# 0  4.20.04 Pharmaceutical products and industry, ...
# 1  3.10.01 Agricultural structures and holdings, ...
# 2  2.50.03 Securities and financial markets, stoc...
# 3  3.70.12 Waste management, domestic waste, pack...
# 4             3.60.06 Trans-European energy networks
#
#                                          key_players  \
# 0  {'European Parliament': [{'Joint committee res...
# 1  {'European Parliament': [{'Joint committee res...
# 2  {'European Parliament': [{'Committee responsib...
# 3  {'European Parliament': [{'Joint committee res...
# 4  {'European Parliament': [{'Joint committee res...
# 0  {'European Parliament': [{'Committee responsib...
# 1                                                NaN
# 2  {'European Parliament': [{'Committee responsib...
# 3  {'European Parliament': [{'Committee responsib...
# 4  {'European Parliament': [{'Committee responsib...
# 0  {'European Parliament': [{'Committee responsib...
# 1  {'European Parliament': [{'Committee responsib...
# 2  {'European Parliament': [{'Committee responsib...
# 3  {'European Parliament': [{'Committee responsib...
# 4  {'European Parliament': [{'Committee responsib...
# 5  {'European Parliament': [{'Committee responsib...
# 6  {'European Parliament': [{'Committee responsib...
# 7  {'European Parliament': [{'Committee responsib...
# 8  {'European Parliament': [{'Committee responsib...
# 9  {'European Parliament': [{'Committee responsib...
# 0  {'European Parliament': [{'Joint committee res...
# 1  {'European Parliament': [{'Joint committee res...
# 2  {'European Parliament': [{'Committee responsib...
# 3  {'European Parliament': [{'Committee responsib...
# 4  {'European Parliament': [{'Committee responsib...
#
#                                           key_events  \
# 0  {'Legislative proposal published': {'Date': '0...
# 1  {'Legislative proposal published': {'Date': '1...
# 2  {'Legislative proposal published': {'Date': '1...
# 3  {'Legislative proposal published': {'Date': '1...
# 4  {'Legislative proposal published': {'Date': '1...
# 0  {'Legislative proposal published': {'Date': '1...
# 1                                                 {}
# 2  {'Legislative proposal published': {'Date': '0...
# 3  {'Legislative proposal published': {'Date': '2...
# 4  {'Legislative proposal published': {'Date': '0...
# 0  {'Legislative proposal published': {'Date': '0...
# 1  {'Legislative proposal published': {'Date': '1...
# 2  {'Legislative proposal published': {'Date': '0...
# 3  {'Legislative proposal published': {'Date': '1...
# 4  {'Legislative proposal published': {'Date': '1...
# 5  {'Legislative proposal published': {'Date': '2...
# 6  {'Legislative proposal published': {'Date': '0...
# 7  {'Legislative proposal published': {'Date': '0...
# 8  {'Legislative proposal published': {'Date': '1...
# 9  {'Legislative proposal published': {'Date': '0...
# 0  {'Legislative proposal published': {'Date': '0...
# 1  {'Legislative proposal published': {'Date': '1...
# 2  {'Legislative proposal published': {'Date': '2...
# 3  {'Legislative proposal published': {'Date': '1...
# 4  {'Legislative proposal published': {'Date': '1...
#
#                                documentation_gateway  \
# 0  [{'Institution': 'European Commission', 'Docum...
# 1  [{'Institution': 'European Commission', 'Docum...
# 2  [{'Institution': 'European Commission', 'Docum...
# 3  [{'Institution': 'European Commission', 'Docum...
# 4  [{'Institution': 'European Commission', 'Docum...
# 0  [{'Institution': 'European Commission', 'Docum...
# 1                                                NaN
# 2  [{'Institution': 'European Commission', 'Docum...
# 3  [{'Institution': 'European Commission', 'Docum...
# 4  [{'Institution': 'European Commission', 'Docum...
# 0  [{'Institution': 'European Commission', 'Docum...
# 1  [{'Institution': 'European Commission', 'Docum...
# 2  [{'Institution': 'European Commission', 'Docum...
# 3  [{'Institution': 'European Commission', 'Docum...
# 4  [{'Institution': 'European Commission', 'Docum...
# 5  [{'Institution': 'European Commission', 'Docum...
# 6  [{'Institution': 'European Commission', 'Docum...
# 7  [{'Institution': 'European Commission', 'Docum...
# 8  [{'Institution': 'European Commission', 'Docum...
# 9  [{'Institution': 'European Commission', 'Docum...
# 0  [{'Institution': 'European Commission', 'Docum...
# 1  [{'Institution': 'European Commission', 'Docum...
# 2  [{'Institution': 'European Commission', 'Docum...
# 3  [{'Institution': 'European Commission', 'Docum...
# 4  [{'Institution': 'European Commission', 'Docum...
#
#                                         transparency  final_act  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2  {'Other Members': [{'Name': [{'text': 'ASENS L...        NaN
# 3  {'Rapporteurs, Shadow Rapporteurs and Committe...        NaN
# 4                                                NaN        NaN
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3  {'Rapporteurs, Shadow Rapporteurs and Committe...        NaN
# 4                                                NaN        NaN
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3  {'Rapporteurs, Shadow Rapporteurs and Committe...        NaN
# 4                                                NaN        NaN
# 5  {'Rapporteurs, Shadow Rapporteurs and Committe...        NaN
# 6                                                NaN        NaN
# 7                                                NaN        NaN
# 8                                                NaN        NaN
# 9  {'Rapporteurs, Shadow Rapporteurs and Committe...        NaN
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
#
#    is_legislative_proposal  ... final_act_text final_act_url  \
# 0                    False  ...            NaN           NaN
# 1                     True  ...            NaN           NaN
# 2                     True  ...            NaN           NaN
# 3                     True  ...            NaN           NaN
# 4                     True  ...            NaN           NaN
# 0                     True  ...            NaN           NaN
# 1                    False  ...            NaN           NaN
# 2                    False  ...            NaN           NaN
# 3                     True  ...            NaN           NaN
# 4                     True  ...            NaN           NaN
# 0                     True  ...            NaN           NaN
# 1                     True  ...            NaN           NaN
# 2                     True  ...            NaN           NaN
# 3                     True  ...            NaN           NaN
# 4                     True  ...            NaN           NaN
# 5                     True  ...            NaN           NaN
# 6                     True  ...            NaN           NaN
# 7                    False  ...            NaN           NaN
# 8                     True  ...            NaN           NaN
# 9                     True  ...            NaN           NaN
# 0                     True  ...            NaN           NaN
# 1                     True  ...            NaN           NaN
# 2                     True  ...            NaN           NaN
# 3                     True  ...            NaN           NaN
# 4                     True  ...            NaN           NaN
#
#                                     proposal_summary resolution_text_2  \
# 0  The European Commission's proposed Justice Pro...              None
# 1                                                NaN              None
# 2  The European Commission has proposed a regulat...              None
# 3  The proposed 'AgoraEU' programme, spanning fro...              None
# 4  The "Global Europe" legislative proposal, intr...              None
# 0                                                NaN              None
# 1                                                NaN              None
# 2  The European Commission has proposed amendment...              None
# 3  The European Commission has introduced a legis...              None
# 4  The European Commission has proposed the "Peri...              None
# 0  The European Commission has proposed a new reg...              None
# 1  The European Commission has proposed a series ...              None
# 2  The European Commission has proposed a revisio...              None
# 3  The European Commission has proposed a new reg...              None
# 4                                                NaN              None
# 5  The European Commission has proposed a legisla...              None
# 6  The European Commission has introduced a new r...              None
# 7                                                NaN              None
# 8                                                NaN              None
# 9  The European Commission has proposed an amendm...              None
# 0  The European Commission has proposed a new reg...              None
# 1                                                NaN              None
# 2  The European Commission has proposed amendment...              None
# 3                                                NaN              None
# 4  The European Commission's legislative proposal...              None
#
#   proposition_text_2 text_adopted_others_2 resolution_text_3  \
# 0               None                  None              None
# 1               None                  None              None
# 2               None                  None              None
# 3               None                  None              None
# 4               None                  None              None
# 0               None                  None              None
# 1               None                  None              None
# 2               None                  None              None
# 3               None                  None              None
# 4               None                  None              None
# 0               None                  None              None
# 1               None                  None              None
# 2               None                  None              None
# 3               None                  None              None
# 4               None                  None              None
# 5               None                  None              None
# 6               None                  None              None
# 7               None                  None              None
# 8               None                  None              None
# 9               None                  None              None
# 0               None                  None              None
# 1               None                  None              None
# 2               None                  None              None
# 3               None                  None              None
# 4               None                  None              None
#
#   proposition_text_3 text_adopted_others_3 final_act_summary
# 0               None                  None              None
# 1               None                  None              None
# 2               None                  None              None
# 3               None                  None              None
# 4               None                  None              None
# 0               None                  None              None
# 1               None                  None              None
# 2               None                  None              None
# 3               None                  None              None
# 4               None                  None              None
# 0               None                  None              None
# 1               None                  None              None
# 2               None                  None              None
# 3               None                  None              None
# 4               None                  None              None
# 5               None                  None              None
# 6               None                  None              None
# 7               None                  None              None
# 8               None                  None              None
# 9               None                  None              None
# 0               None                  None              None
# 1               None                  None              None
# 2               None                  None              None
# 3               None                  None              None
# 4               None                  None              None
#
# [25 rows x 36 columns]

# %% [markdown]
# ### 2.2 Handle completed procedures

# %%
df_final_act_proposal = pd.concat([df_final_act_proposal_summary_1, df_final_act_proposal_summary_2, df_final_act_proposal_summary_3, df_final_act_proposal_summary_4])

# %%
df_final_act = df_final_act.merge(df_final_act_proposal[['reference', 'proposal_summary']], on='reference', how='left')

# %%
df_final_act = df_final_act.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'Unnamed: 0.2'])

# %%
# Adding missing columns that are present in the PostgreSQL database to avoid unmatching columns
df_final_act['resolution_text_2'] = None
df_final_act['proposition_text_2'] = None
df_final_act['text_adopted_others_2'] = None
df_final_act['resolution_text_3'] = None
df_final_act['proposition_text_3'] = None
df_final_act['text_adopted_others_3'] = None

# %% [markdown]
# ### 2.3 Fix problematic columns (not readable as a SQL database) for both ongoing and completed procedures

# %%
def fix_json_format(val):
    if pd.isna(val) or val == "":
        return val
    try:
        # Reads the string as a dictionary
        data = literal_eval(str(val))
        # Returns the string as a standard JSON
        return json.dumps(data)
    except (ValueError, SyntaxError):
        # If the value is not a string, keep it as it already is
        return val

# %%
# Fix problematic columns
columns_to_fix = ['key_players', 'key_events']
for col in columns_to_fix:
    if col in df_final_act.columns:
        df_final_act[col] = df_final_act[col].apply(fix_json_format)

# %%
# Fix problematic columns
columns_to_fix = ['key_players', 'key_events']
for col in columns_to_fix:
    if col in df_proposal.columns:
        df_proposal[col] = df_proposal[col].apply(fix_json_format)

# %%
# Changes order of the columns to match the one that has been input into PostgreSQL
df_final_act = df_final_act.reindex(['url', 'reference', 'title', 'subjects', 'key_players', 'key_events',
       'documentation_gateway', 'transparency', 'final_act',
       'is_legislative_proposal', 'Procedure reference', 'Procedure type',
       'Procedure subtype', 'Legislative instrument', 'Amendments and repeals',
       'Legal basis', 'Stage reached in procedure', 'Committee dossier',
       'Mandatory consultation of other institutions', 'Other legal basis',
       'legislative_proposal_url', 'legislative_proposal_text',
       'decisions_url_list', 'resolution_text_1', 'position_text_1',
       'text_adopted_others_1', 'resolution_text_2', 'proposition_text_2',
       'text_adopted_others_2', 'resolution_text_3', 'proposition_text_3',
       'text_adopted_others_3', 'final_act_text', 'final_act_url', 
       'proposal_summary', 'final_act_summary'], axis=1)

# %%
# Changes order of the columns to match the one that has been input into PostgreSQL
df_proposal = df_proposal.reindex(['url', 'reference', 'title', 'subjects', 'key_players', 'key_events',
       'documentation_gateway', 'transparency', 'final_act',
       'is_legislative_proposal', 'Procedure reference', 'Procedure type',
       'Procedure subtype', 'Legislative instrument', 'Amendments and repeals',
       'Legal basis', 'Stage reached in procedure', 'Committee dossier',
       'Mandatory consultation of other institutions', 'Other legal basis',
       'legislative_proposal_url', 'legislative_proposal_text',
       'decisions_url_list', 'resolution_text_1', 'position_text_1',
       'text_adopted_others_1', 'resolution_text_2', 'proposition_text_2',
       'text_adopted_others_2', 'resolution_text_3', 'proposition_text_3',
       'text_adopted_others_3', 'final_act_text', 'final_act_url', 'proposal_summary', 'final_act_summary'], axis=1)

# %% [markdown]
# ### 2.4 Concat and save the data

# %%
df_all = pd.concat([df_proposal, df_final_act]).reset_index().drop(columns='index')

# %%
df_all
# Out:
#                                                   url       reference  \
# 0   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0255(COD)
# 1   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0405(COD)
# 2   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0540(COD)
# 3   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0550(COD)
# 4   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0227(COD)
# 5   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0423(COD)
# 6   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0422(COD)
# 7   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0385(COD)
# 8   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0103(COD)
# 9   https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0258(COD)
# 10  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0590(COD)
# 11  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0237(COD)
# 12  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0312(COD)
# 13  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0241(COD)
# 14  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0424(COD)
# 15  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0071(COD)
# 16  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0381(COD)
# 17  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0383(COD)
# 18  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0396(COD)
# 19  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0073(COD)
# 20  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0384(COD)
# 21  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0240(COD)
# 22  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0361(COD)
# 23  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0395(COD)
# 24  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0399(COD)
# 25  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0023(COD)
# 26  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0012(COD)
# 27  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0077(COD)
# 28  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0021(COD)
# 29  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0084(COD)
# 30  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0085(COD)
# 31  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0058(COD)
# 32  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0039(COD)
# 33  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0051(COD)
# 34  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0188(COD)
# 35  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0129(COD)
# 36  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0104(COD)
# 37  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0526(COD)
# 38  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0044(COD)
# 39  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0070(COD)
# 40  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0022(COD)
# 41  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0074(COD)
# 42  https://oeil.europarl.europa.eu/oeil/en/proced...  2025/0056(COD)
#
#                                                 title  \
# 0                         Justice programme 2028-2034
# 1   Placing on the market of genetically modified ...
# 2   Union support for asylum, migration and integr...
# 3                       'AgoraEU' programme 2028–2034
# 4                                       Global Europe
# 5   Calculation of emission credits for heavy-duty...
# 6                                                 NaN
# 7        Amendments to the Critical Raw Materials Act
# 8   Incentivising defence-related investments in t...
# 9   Pericles V exchange, assistance and training p...
# 10  Establishing the Single Market and Customs Pro...
# 11  Amendments to the Common Market Organisation (...
# 12  Economic and budgetary surveillance of Member ...
# 13               Common Agricultural Policy 2028–2034
# 14  Exemption of certain N2 electric vehicles from...
# 15  Amending certain agricultural products Regulat...
# 16  Banks and financial markets: settlement finali...
# 17  Further development of capital market integrat...
# 18  Suspending the application of the rules on the...
# 19  European Globalisation Adjustment Fund for Dis...
# 20         Monitoring and controlling drug precursors
# 21  European Fund for economic, social and territo...
# 22  Sustainability-related disclosures in the fina...
# 23  Suspending the application of the rules on the...
# 24   Trans-European energy infrastructure: guidelines
# 25  Insolvency proceedings: replacing Annexes A and B
# 26  Additional customs duties on imports of certai...
# 27  Capital Requirements Regulation (CRR): require...
# 28  Modification of customs duties applicable to i...
# 29  Amending ERDF, Cohesion Fund and Just Transiti...
# 30  European Social Fund (ESF+): specific measures...
# 31  Habitats Directive: protection status of the w...
# 32  Carbon Border Adjustment Mechanism: simplifica...
# 33  Role of gas storage for securing gas supplies ...
# 34  Extension of the derogation for heavy-duty veh...
# 35  Amending Regulation as regards obligations of ...
# 36  Additional assistance and further flexibility ...
# 37  Dates of application and transitional provisio...
# 38  Certain corporate sustainability reporting and...
# 39  Additional flexibility as regards the calculat...
# 40  Securities settlement in the EU and central se...
# 41  Extension of the timeframe for the establishme...
# 42  Common rules for imports: suspension of certai...
#
#                                              subjects  \
# 0   7.40.02 Judicial cooperation in civil and comm...
# 1   3.10.09.06 Agro-genetics, GMOs, 4.60.02 Consum...
# 2   7.10 Free movement and integration of third-co...
# 3   1.20 Citizen's rights, 4.10.03 Child protectio...
# 4   6.20 Common commercial policy in general, 8.70...
# 5   3.20.05 Road transport: passengers and freight...
# 6                                                 NaN
# 7   3.40 Industrial policy, 3.40.14 Industrial com...
# 8   3.40.09 Defence and arms industry, 4.70.01 Str...
# 9   5.20.02 Single currency, euro, euro area, 7.30...
# 10  2.10.01 Customs union, tax and duty-free, Comm...
# 11  3.10 Agricultural policy and economies, 3.10.0...
# 12  4.70.01 Structural funds, investment funds in ...
# 13  3.10 Agricultural policy and economies, 3.10.0...
# 14  3.20.06 Transport regulations, road safety, ro...
# 15  3.10 Agricultural policy and economies, 3.10.0...
# 16  2.50.03 Securities and financial markets, stoc...
# 17  2.50.03 Securities and financial markets, stoc...
# 18  3.70.12 Waste management, domestic waste, pack...
# 19  4.15.05 Industrial restructuring, job losses, ...
# 20  4.20.04 Pharmaceutical products and industry, ...
# 21  3.10.01 Agricultural structures and holdings, ...
# 22  2.50.03 Securities and financial markets, stoc...
# 23  3.70.12 Waste management, domestic waste, pack...
# 24             3.60.06 Trans-European energy networks
# 25  3.45.01 Company law, 3.45.03 Financial managem...
# 26  6.20.03 Bilateral economic and trade agreement...
# 27  2.50.03 Securities and financial markets, stoc...
# 28  6.20.03 Bilateral economic and trade agreement...
# 29  4.70.01 Structural funds, investment funds in ...
# 30  4.10.15 European Social Fund (ESF), Fund for E...
# 31  3.10.04.02 Animal protection, 3.70.01 Protecti...
# 32  2.10.01 Customs union, tax and duty-free, Comm...
# 33  3.60.03 Gas, electricity, natural gas, biogas,...
# 34  2.10.03 Standardisation, EC/EU standards and t...
# 35  3.70.12 Waste management, domestic waste, pack...
# 36  3.70.11 Natural disasters, Solidarity Fund, 4....
# 37   3.40.01 Chemical industry, fertilizers, plastics
# 38  3.45.01 Company law, 3.70.20 Sustainable devel...
# 39  2.10.03 Standardisation, EC/EU standards and t...
# 40  2.50.03 Securities and financial markets, stoc...
# 41  7.30.30 Action to combat crime, 7.40.04 Judici...
# 42  6.20.02 Export/import control, trade defence, ...
#
#                                           key_players  \
# 0   {"European Parliament": [{"Joint committee res...
# 1   {"European Parliament": [{"Joint committee res...
# 2   {"European Parliament": [{"Committee responsib...
# 3   {"European Parliament": [{"Joint committee res...
# 4   {"European Parliament": [{"Joint committee res...
# 5   {"European Parliament": [{"Committee responsib...
# 6                                                 NaN
# 7   {"European Parliament": [{"Committee responsib...
# 8   {"European Parliament": [{"Committee responsib...
# 9   {"European Parliament": [{"Committee responsib...
# 10  {"European Parliament": [{"Committee responsib...
# 11  {"European Parliament": [{"Committee responsib...
# 12  {"European Parliament": [{"Committee responsib...
# 13  {"European Parliament": [{"Committee responsib...
# 14  {"European Parliament": [{"Committee responsib...
# 15  {"European Parliament": [{"Committee responsib...
# 16  {"European Parliament": [{"Committee responsib...
# 17  {"European Parliament": [{"Committee responsib...
# 18  {"European Parliament": [{"Committee responsib...
# 19  {"European Parliament": [{"Committee responsib...
# 20  {"European Parliament": [{"Joint committee res...
# 21  {"European Parliament": [{"Joint committee res...
# 22  {"European Parliament": [{"Committee responsib...
# 23  {"European Parliament": [{"Committee responsib...
# 24  {"European Parliament": [{"Committee responsib...
# 25  {"European Parliament": [{"Committee responsib...
# 26  {"European Parliament": [{"Committee responsib...
# 27  {"European Parliament": [{"Committee responsib...
# 28  {"European Parliament": [{"Committee responsib...
# 29  {"European Parliament": [{"Committee responsib...
# 30  {"European Parliament": [{"Committee responsib...
# 31  {"European Parliament": [{"Committee responsib...
# 32  {"European Parliament": [{"Committee responsib...
# 33  {"European Parliament": [{"Committee responsib...
# 34  {"European Parliament": [{"Committee responsib...
# 35  {"European Parliament": [{"Committee responsib...
# 36  {"European Parliament": [{"Committee responsib...
# 37  {"European Parliament": [{"Committee responsib...
# 38  {"European Parliament": [{"Committee responsib...
# 39  {"European Parliament": [{"Committee responsib...
# 40  {"European Parliament": [{"Committee responsib...
# 41  {"European Parliament": [{"Committee responsib...
# 42  {"European Parliament": [{"Committee responsib...
#
#                                            key_events  \
# 0   {"Legislative proposal published": {"Date": "0...
# 1   {"Legislative proposal published": {"Date": "1...
# 2   {"Legislative proposal published": {"Date": "1...
# 3   {"Legislative proposal published": {"Date": "1...
# 4   {"Legislative proposal published": {"Date": "1...
# 5   {"Legislative proposal published": {"Date": "1...
# 6                                                  {}
# 7   {"Legislative proposal published": {"Date": "0...
# 8   {"Legislative proposal published": {"Date": "2...
# 9   {"Legislative proposal published": {"Date": "0...
# 10  {"Legislative proposal published": {"Date": "0...
# 11  {"Legislative proposal published": {"Date": "1...
# 12  {"Legislative proposal published": {"Date": "0...
# 13  {"Legislative proposal published": {"Date": "1...
# 14  {"Legislative proposal published": {"Date": "1...
# 15  {"Legislative proposal published": {"Date": "2...
# 16  {"Legislative proposal published": {"Date": "0...
# 17  {"Legislative proposal published": {"Date": "0...
# 18  {"Legislative proposal published": {"Date": "1...
# 19  {"Legislative proposal published": {"Date": "0...
# 20  {"Legislative proposal published": {"Date": "0...
# 21  {"Legislative proposal published": {"Date": "1...
# 22  {"Legislative proposal published": {"Date": "2...
# 23  {"Legislative proposal published": {"Date": "1...
# 24  {"Legislative proposal published": {"Date": "1...
# 25  {"Legislative proposal published": {"Date": "1...
# 26  {"Legislative proposal published": {"Date": "0...
# 27  {"Legislative proposal published": {"Date": "3...
# 28  {"Legislative proposal published": {"Date": "2...
# 29  {"Legislative proposal published": {"Date": "0...
# 30  {"Legislative proposal published": {"Date": "0...
# 31  {"Legislative proposal published": {"Date": "0...
# 32  {"Legislative proposal published": {"Date": "2...
# 33  {"Legislative proposal published": {"Date": "0...
# 34  {"Legislative proposal published": {"Date": "2...
# 35  {"Legislative proposal published": {"Date": "2...
# 36  {"Legislative proposal published": {"Date": "2...
# 37  {"Legislative proposal published": {"Date": "0...
# 38  {"Legislative proposal published": {"Date": "2...
# 39  {"Legislative proposal published": {"Date": "0...
# 40  {"Legislative proposal published": {"Date": "1...
# 41  {"Legislative proposal published": {"Date": "0...
# 42  {"Legislative proposal published": {"Date": "0...
#
#                                 documentation_gateway  \
# 0   [{'Institution': 'European Commission', 'Docum...
# 1   [{'Institution': 'European Commission', 'Docum...
# 2   [{'Institution': 'European Commission', 'Docum...
# 3   [{'Institution': 'European Commission', 'Docum...
# 4   [{'Institution': 'European Commission', 'Docum...
# 5   [{'Institution': 'European Commission', 'Docum...
# 6                                                 NaN
# 7   [{'Institution': 'European Commission', 'Docum...
# 8   [{'Institution': 'European Commission', 'Docum...
# 9   [{'Institution': 'European Commission', 'Docum...
# 10  [{'Institution': 'European Commission', 'Docum...
# 11  [{'Institution': 'European Commission', 'Docum...
# 12  [{'Institution': 'European Commission', 'Docum...
# 13  [{'Institution': 'European Commission', 'Docum...
# 14  [{'Institution': 'European Commission', 'Docum...
# 15  [{'Institution': 'European Commission', 'Docum...
# 16  [{'Institution': 'European Commission', 'Docum...
# 17  [{'Institution': 'European Commission', 'Docum...
# 18  [{'Institution': 'European Commission', 'Docum...
# 19  [{'Institution': 'European Commission', 'Docum...
# 20  [{'Institution': 'European Commission', 'Docum...
# 21  [{'Institution': 'European Commission', 'Docum...
# 22  [{'Institution': 'European Commission', 'Docum...
# 23  [{'Institution': 'European Commission', 'Docum...
# 24  [{'Institution': 'European Commission', 'Docum...
# 25  [{'Institution': 'European Commission', 'Docum...
# 26  [{'Institution': 'European Commission', 'Docum...
# 27  [{'Institution': 'European Commission', 'Docum...
# 28  [{'Institution': 'European Commission', 'Docum...
# 29  [{'Institution': 'European Commission', 'Docum...
# 30  [{'Institution': 'European Commission', 'Docum...
# 31  [{'Institution': 'European Commission', 'Docum...
# 32  [{'Institution': 'European Commission', 'Docum...
# 33  [{'Institution': 'European Commission', 'Docum...
# 34  [{'Institution': 'European Commission', 'Docum...
# 35  [{'Institution': 'European Commission', 'Docum...
# 36  [{'Institution': 'European Commission', 'Docum...
# 37  [{'Institution': 'European Commission', 'Docum...
# 38  [{'Institution': 'European Commission', 'Docum...
# 39  [{'Institution': 'European Commission', 'Docum...
# 40  [{'Institution': 'European Commission', 'Docum...
# 41  [{'Institution': 'European Commission', 'Docum...
# 42  [{'Institution': 'European Commission', 'Docum...
#
#                                          transparency  \
# 0                                                 NaN
# 1                                                 NaN
# 2   {'Other Members': [{'Name': [{'text': 'ASENS L...
# 3   {'Rapporteurs, Shadow Rapporteurs and Committe...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   {'Rapporteurs, Shadow Rapporteurs and Committe...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 14                                                NaN
# 15  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 26                                                NaN
# 27  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 28  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 29  {'Other Members': [{'Name': [{'text': 'KATAINE...
# 30  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 31  {'Other Members': [{'Name': [{'text': 'LUENA C...
# 32  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 33  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 34                                                NaN
# 35  {'Rapporteurs, Shadow Rapporteurs and Committe...
# 36                                                NaN
# 37                                                NaN
# 38  {'Other Members': [{'Name': [{'text': 'BOCHEŃS...
# 39  {'Other Members': [{'Name': [{'text': 'TAMBURR...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                             final_act  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 26  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 27  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 28  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 29  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 30  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 31  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 32  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 33  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 34  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 35  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 36  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 37  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 38  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 39  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 40  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 41  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
# 42  {'pdfFinal act': '/oeil/en/procedure-file/pdf?...
#
#     is_legislative_proposal  ... resolution_text_2 proposition_text_2  \
# 0                     False  ...              None               None
# 1                      True  ...              None               None
# 2                      True  ...              None               None
# 3                      True  ...              None               None
# 4                      True  ...              None               None
# 5                      True  ...              None               None
# 6                     False  ...              None               None
# 7                     False  ...              None               None
# 8                      True  ...              None               None
# 9                      True  ...              None               None
# 10                     True  ...              None               None
# 11                     True  ...              None               None
# 12                     True  ...              None               None
# 13                     True  ...              None               None
# 14                     True  ...              None               None
# 15                     True  ...              None               None
# 16                     True  ...              None               None
# 17                    False  ...              None               None
# 18                     True  ...              None               None
# 19                     True  ...              None               None
# 20                     True  ...              None               None
# 21                     True  ...              None               None
# 22                     True  ...              None               None
# 23                     True  ...              None               None
# 24                     True  ...              None               None
# 25                     True  ...              None               None
# 26                     True  ...              None               None
# 27                     True  ...              None               None
# 28                     True  ...              None               None
# 29                     True  ...              None               None
# 30                     True  ...              None               None
# 31                     True  ...              None               None
# 32                     True  ...              None               None
# 33                     True  ...              None               None
# 34                     True  ...              None               None
# 35                     True  ...              None               None
# 36                     True  ...              None               None
# 37                     True  ...              None               None
# 38                     True  ...              None               None
# 39                     True  ...              None               None
# 40                     True  ...              None               None
# 41                     True  ...              None               None
# 42                     True  ...              None               None
#
#    text_adopted_others_2 resolution_text_3 proposition_text_3  \
# 0                   None              None               None
# 1                   None              None               None
# 2                   None              None               None
# 3                   None              None               None
# 4                   None              None               None
# 5                   None              None               None
# 6                   None              None               None
# 7                   None              None               None
# 8                   None              None               None
# 9                   None              None               None
# 10                  None              None               None
# 11                  None              None               None
# 12                  None              None               None
# 13                  None              None               None
# 14                  None              None               None
# 15                  None              None               None
# 16                  None              None               None
# 17                  None              None               None
# 18                  None              None               None
# 19                  None              None               None
# 20                  None              None               None
# 21                  None              None               None
# 22                  None              None               None
# 23                  None              None               None
# 24                  None              None               None
# 25                  None              None               None
# 26                  None              None               None
# 27                  None              None               None
# 28                  None              None               None
# 29                  None              None               None
# 30                  None              None               None
# 31                  None              None               None
# 32                  None              None               None
# 33                  None              None               None
# 34                  None              None               None
# 35                  None              None               None
# 36                  None              None               None
# 37                  None              None               None
# 38                  None              None               None
# 39                  None              None               None
# 40                  None              None               None
# 41                  None              None               None
# 42                  None              None               None
#
#    text_adopted_others_3                                     final_act_text  \
# 0                   None                                                NaN
# 1                   None                                                NaN
# 2                   None                                                NaN
# 3                   None                                                NaN
# 4                   None                                                NaN
# 5                   None                                                NaN
# 6                   None                                                NaN
# 7                   None                                                NaN
# 8                   None                                                NaN
# 9                   None                                                NaN
# 10                  None                                                NaN
# 11                  None                                                NaN
# 12                  None                                                NaN
# 13                  None                                                NaN
# 14                  None                                                NaN
# 15                  None                                                NaN
# 16                  None                                                NaN
# 17                  None                                                NaN
# 18                  None                                                NaN
# 19                  None                                                NaN
# 20                  None                                                NaN
# 21                  None                                                NaN
# 22                  None                                                NaN
# 23                  None                                                NaN
# 24                  None                                                NaN
# 25                  None  REGULATION (EU) 2025/2073 OF THE EUROPEAN PARL...
# 26                  None                                                NaN
# 27                  None  REGULATION (EU) 2025/1215 OF THE EUROPEAN PARL...
# 28                  None                                                NaN
# 29                  None  REGULATION (EU) 2025/1914 OF THE EUROPEAN PARL...
# 30                  None  REGULATION (EU) 2025/1913 OF THE EUROPEAN PARL...
# 31                  None  DIRECTIVE (EU) 2025/1237 OF THE EUROPEAN PARLI...
# 32                  None  REGULATION (EU) 2025/2083 OF THE EUROPEAN PARL...
# 33                  None  REGULATION (EU) 2025/1733 OF THE EUROPEAN PARL...
# 34                  None  DIRECTIVE (EU) 2025/2459 OF THE EUROPEAN PARLI...
# 35                  None  REGULATION (EU) 2025/1561 OF THE EUROPEAN PARL...
# 36                  None  REGULATION (EU) 2025/1276 OF THE EUROPEAN PARL...
# 37                  None  REGULATION (EU) 2025/2439 OF THE EUROPEAN PARL...
# 38                  None  DIRECTIVE (EU) 2025/794 OF THE EUROPEAN PARLIA...
# 39                  None  REGULATION (EU) 2025/1214 OF THE EUROPEAN PARL...
# 40                  None  REGULATION (EU) 2025/2075 OF THE EUROPEAN PARL...
# 41                  None  REGULATION (EU) 2025/2082 OF THE EUROPEAN PARL...
# 42                  None                                                NaN
#
#                                         final_act_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 26                                                NaN
# 27  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 28                                                NaN
# 29  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 30  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 31  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 32  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 33  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 34  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 35  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 36  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 37  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 38  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 39  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 40  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 41  https://eur-lex.europa.eu/legal-content/EN/TXT...
# 42                                                NaN
#
#                                      proposal_summary  \
# 0   The European Commission's proposed Justice Pro...
# 1                                                 NaN
# 2   The European Commission has proposed a regulat...
# 3   The proposed 'AgoraEU' programme, spanning fro...
# 4   The "Global Europe" legislative proposal, intr...
# 5                                                 NaN
# 6                                                 NaN
# 7   The European Commission has proposed amendment...
# 8   The European Commission has introduced a legis...
# 9   The European Commission has proposed the "Peri...
# 10  The European Commission has proposed a new reg...
# 11  The European Commission has proposed a series ...
# 12  The European Commission has proposed a revisio...
# 13  The European Commission has proposed a new reg...
# 14                                                NaN
# 15  The European Commission has proposed a legisla...
# 16  The European Commission has introduced a new r...
# 17                                                NaN
# 18                                                NaN
# 19  The European Commission has proposed an amendm...
# 20  The European Commission has proposed a new reg...
# 21                                                NaN
# 22  The European Commission has proposed amendment...
# 23                                                NaN
# 24  The European Commission's legislative proposal...
# 25                                                NaN
# 26  The European Commission has proposed a legisla...
# 27                                                NaN
# 28                                                NaN
# 29  The European Commission has proposed amendment...
# 30  The European Commission has proposed amendment...
# 31  The European Commission has proposed an amendm...
# 32  The European Commission has proposed a regulat...
# 33  The European Commission has proposed a regulat...
# 34  The European Commission has proposed a directi...
# 35  The European Commission has proposed an amendm...
# 36  The European Commission has proposed a legisla...
# 37  The European Commission has proposed a regulat...
# 38  The European Commission has proposed a directi...
# 39                                                NaN
# 40  The European Commission has proposed a regulat...
# 41  The European Commission has proposed an extens...
# 42  The European Commission has proposed a regulat...
#
#                                     final_act_summary
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25  The European Parliament and the Council have a...
# 26                                                NaN
# 27  The European Parliament and the Council have a...
# 28                                                NaN
# 29  The European Parliament and the Council have a...
# 30  The European Parliament and the Council have a...
# 31  The European Parliament and the Council of the...
# 32  The European Parliament and the Council have a...
# 33  The European Parliament and the Council have a...
# 34  The European Parliament and the Council have a...
# 35  The European Parliament and the Council have a...
# 36  The European Parliament and the Council have a...
# 37  The European Parliament and the Council have a...
# 38  The European Parliament and the Council have a...
# 39  The European Parliament and the Council have a...
# 40  The European Parliament and the Council have a...
# 41  The European Parliament and the Council have a...
# 42                                                NaN
#
# [43 rows x 36 columns]

# %%
# Save the data
df_final_act.to_csv('completed_proc_clean_2025.csv', index=False, encoding='utf-8')
df_proposal.to_csv('ongoing_proc_clean_2025.csv', index=False, encoding='utf-8')
df_all.to_csv('procedures_2025.csv', index=False, encoding='utf-8')
